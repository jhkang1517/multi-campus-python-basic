# %%
import pandas as pd
import numpy as np
import datetime

# %%
# 3조 기준금리 data 다운받아 사용.
# json형식이기 때문에, test 이후 csv파일로 새롭게 변환하였습니다.

df = pd.read_json('기준금리.json')
df = df.rename(columns={'baseRate':'BASERATE'})
df = df[0:30]
# df['date'] = df['date'].apply(lambda x: pd.to_datetime(str(x), format='%Y%m%d'))
df = df.set_index(df['date'])
df = df.drop(columns=['date'])
df
# Out:
#           BASERATE
# date
# 20181130      1.75
# 20171130      1.50
# 20160609      1.25
# 20150611      1.50
# 20150312      1.75
# 20141015      2.00
# 20140814      2.25
# 20130509      2.50
# 20121011      2.75
# 20120712      3.00
# 20110610      3.25
# 20110310      3.00
# 20110113      2.75
# 20101116      2.50
# 20100709      2.25
# 20090212      2.00
# 20090109      2.50
# 20081211      3.00
# 20081107      4.00
# 20081027      4.25
# 20081009      5.00
# 20080807      5.25
# 20070809      5.00
# 20070712      4.75
# 20060810      4.50
# 20060608      4.25
# 20060209      4.00
# 20051208      3.75
# 20051011      3.50
# 20041111      3.25

# %%
df.to_csv("기준금리.csv")

# %%
baserate = pd.read_csv("기준금리.csv")
baserate = baserate.set_index(baserate['date'])
baserate = baserate.drop(columns=['date'])
baserate
# Out:
#           BASERATE
# date
# 20181130      1.75
# 20171130      1.50
# 20160609      1.25
# 20150611      1.50
# 20150312      1.75
# 20141015      2.00
# 20140814      2.25
# 20130509      2.50
# 20121011      2.75
# 20120712      3.00
# 20110610      3.25
# 20110310      3.00
# 20110113      2.75
# 20101116      2.50
# 20100709      2.25
# 20090212      2.00
# 20090109      2.50
# 20081211      3.00
# 20081107      4.00
# 20081027      4.25
# 20081009      5.00
# 20080807      5.25
# 20070809      5.00
# 20070712      4.75
# 20060810      4.50
# 20060608      4.25
# 20060209      4.00
# 20051208      3.75
# 20051011      3.50
# 20041111      3.25

# %%
import matplotlib
baserate.plot(kind='line')

# %%
df.plot?
