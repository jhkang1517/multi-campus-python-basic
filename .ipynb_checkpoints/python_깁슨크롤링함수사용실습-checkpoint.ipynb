# %%
import Gibson_Crawling_Final

# %%
Gibson_Crawling_Final.introduction
# Out:
# "Les-Paul, SG, ES, Acoustic, Designer, Bass 를 'crwaling( )'안에 입력하세요.\n입력한 값의 모든 깁슨 모델을 제공합니다. "

# %%
Gibson_Crawling_Final.maker
# Out:
# 'jungho kang'

# %%
Gibson_Crawling_Final.crl.run('Les-Paul')
# Out:
# [{'link': 'https://www.gibson.com/Guitar/CUSFXC951/60th-Anniversary-1959-Les-Paul-Standard',
#   'name': '60th Anniversary 1959 Les Paul Standard',
#   'price': ' $6,499.00'},
#  {'link': 'https://www.gibson.com/Guitar/USAQ17249/Les-Paul-Modern',
#   'name': 'Les Paul Modern',
#   'price': ' $2,799.00'},
#  {'link': 'https://www.gibson.com/Guitar/CUSCB4758/1957-Les-Paul-Junior-Reissue',
#   'name': '1957 Les Paul Junior Reissue',
#   'price': ' $3,799.00'},
#  {'link': 'https://www.gibson.com/Guitar/USAI9Q269/Les-Paul-Classic',
#   'name': 'Les Paul Classic',
#   'price': ' $1,999.00'},
#  {'link': 'https://www.gibson.com/Guitar/CUSGFA436/1958-Les-Paul-Junior-Double-Cut-Reissue',
#   'name': '1958 Les Paul Junior Double Cut Reissue',
#   'price': ' $3,799.00'},
#  {'link': 'https://www.gibson.com/Guitar/CUSNZT900/1957-Les-Paul-Special-Single-Cut-Reissue-VOS',
#   'name': '1957 Les Paul Special Single Cut Reissue VOS',
#   'price': ' $3,799.00'},
# ...

# %%
Gibson_Crawling_Final.crl.run('SG')
# Out:
# [{'link': 'https://www.gibson.com/Guitar/USAC9L891/SG-Modern',
#   'name': 'SG Modern',
#   'price': ' $1,999.00'},
#  {'link': 'https://www.gibson.com/Guitar/USA8LG109/SG-Standard',
#   'name': 'SG Standard',
#   'price': ' $1,499.00'},
#  {'link': 'https://www.gibson.com/Guitar/USAG74273/SG-Tribute',
#   'name': 'SG Tribute',
#   'price': ' $1,099.00'},
#  {'link': 'https://www.gibson.com/Guitar/CUSNAE888/1961-Les-Paul-SG-Standard-Reissue-Stop-Bar',
#   'name': '1961 Les Paul SG Standard Reissue Stop Bar',
#   'price': ' $4,199.00'},
#  {'link': 'https://www.gibson.com/Guitar/CUSFUM384/1964-SG-Standard-Reissue-w-Maestro-Vibrola',
#   'name': '1964 SG Standard Reissue w/ Maestro Vibrola',
#   'price': ' $4,599.00'},
#  {'link': 'https://www.gibson.com/Guitar/CUSGSY394/1963-Les-Paul-SG-Custom-Reissue-w-Maestro-Vibrola',
#   'name': '1963 Les Paul SG Custom Reissue w/ Maestro Vibrola',
#   'price': ' $6,699.00'},
# ...

# %%
Gibson_Crawling_Final.crl.run('ES')
# Out:
# [{'link': 'https://www.gibson.com/Guitar/MEMMKD961/ES-335-Dot',
#   'name': 'ES-335 Dot ',
#   'price': ' $2,999.00'},
#  {'link': 'https://www.gibson.com/Guitar/MEM7X3642/ES-339-Figured',
#   'name': 'ES-339 Figured',
#   'price': ' $2,899.00'},
#  {'link': 'https://www.gibson.com/Guitar/MEMDWN425/ES-335-Satin',
#   'name': 'ES-335 Satin',
#   'price': ' $2,599.00'},
#  {'link': 'https://www.gibson.com/Guitar/MEM8M2445/ES-335-Studio',
#   'name': 'ES-335 Studio ',
#   'price': ' $1,999.00'},
#  {'link': 'https://www.gibson.com/Guitar/MEM6JM545/ES-235-Gloss',
#   'name': 'ES-235 Gloss ',
#   'price': ' $1,799.00'},
#  {'link': 'https://www.gibson.com/Guitar/MEM2UP792/ES-335-Figured',
#   'name': 'ES-335 Figured ',
#   'price': ' $3,699.00'},
#  {'link': 'https://www.gibson.com/Guitar/MEMYIK911/ES-335-Figured',
#   'name': 'ES-335 Figured',
#   'price': ' $3,699.00'},
#  {'link': 'https://www.gibson.com/Guitar/MEM2UE649/ES-275T-Gloss',
#   'name': 'ES-275T Gloss',
# ...

# %%
Gibson_Crawling_Final.crl.run('Acoustic')
# Out:
# [{'link': 'https://www.gibson.com/Guitar/ACC3NY964/125th-Anniversary-J-45',
#   'name': '125th Anniversary J-45',
#   'price': ' $4,999.00'},
#  {'link': 'https://www.gibson.com/Guitar/ACCVID935/125th-Anniversary-Hummingbird',
#   'name': '125th Anniversary Hummingbird',
#   'price': ' $5,499.00'},
#  {'link': 'https://www.gibson.com/Guitar/ACC5VI857/125th-Anniversary-SJ-200',
#   'name': '125th Anniversary SJ-200',
#   'price': ' $6,149.00'},
#  {'link': 'https://www.gibson.com/Guitar/ACCDUQ766/J-45-Walnut-M-Antique-Natural',
#   'name': 'J-45 Walnut M Antique Natural',
#   'price': ' $1,799.00'},
#  {'link': 'https://www.gibson.com/Guitar/ACC7JP801/J-45-Standard',
#   'name': 'J-45 Standard',
#   'price': ' $2,749.00'},
#  {'link': 'https://www.gibson.com/Guitar/ACCAQJ999/J-45-Rosewood-M',
#   'name': 'J-45 Rosewood M',
#   'price': ' $2,199.00'},
#  {'link': 'https://www.gibson.com/Guitar/ACCVFB499/Hummingbird-M-Mahogany',
#   'name': 'Hummingbird M Mahogany',
# ...
