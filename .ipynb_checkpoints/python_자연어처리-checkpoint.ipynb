# %%
"""
1. 자연어 처리란?
인간의 언어 현상을 컴퓨터와 같은 기계를 이요해서 모사할 수 있도록 연구하고 구현하는 것
단어(keyword)가 아닌 문장을 입력해도 컴퓨터가 이를 이해하는 것

1-1. 전통적인 프로그래밍 언어
기계가 이해할 수 있는 프로그래밍 언어로 명령을 내리고, 그 결과를 사용자에게 전달하는 방식
우리가 직접 컴퓨터 언어를 습득해야하는 단점이 존재한다. 

1-2. 자연어처리(NLP)
기계가 사람의 언어를 자연어처리(NLP)를 통해 이해하고, 그 결과를 사용자에게 전달하는 방식 
즉, 기계가 인간의 언어를 이해해서 소통하는 것을 말한다. 


2. 왜 자연어 처리에 관심을 가져야 하는가?
2-1. 비정형 데이터의 중요성 
2-1-1. 정형테이터
사전 정의된 모델을 통해 구조화된 데이터 Ex) 엑셀

2-1-2. 비정형 데이터
상당한 정제작업을 필요로 하는 데이터 Ex) text, e-mail, 웹사이트 
비정형 데이터는 전체 데이터에서 80%를 차지한다. 따라서 이러한 비정형 데이터의 필요성이 증가

2-2. 온라인 데이터의 중요성
온라인 상에는 소셜미디어, 블로그, 뉴스등 다양한 데이터들이 존재하는데, 기업은 이러한 온라인 평판을 관리하는 것이
매우 중요하다. 따라서 이러한 온라인 데이터를 잘 파악해야하는 필요성이 증가

2-3. 소통 패러다임의 변화
컴퓨터와 인간의 소통이 자연스러운 대화의 형태로 변화


3. 자연어 처리가 어려운 이유
자연어 처리가 좋은 성능을 내기 위해서는 '명확'해야 한다. 

3-1. 동형이의어: 철자와 발음이 둘 다 동일
3-2. 동음이형어: 철자는 다르나 발음이 같음 
3-3. 다의어 (언어의 모호성)
bolt = 전기, 나사 볼트 

4. 킹국어 자연어 처리는 왜 어려운가?
4-1. 구어와 문어의 차이 

5. 자연어 처리 시장 전망
가장 빠르게 성장하고 있는 분야. 텍스트 분석과 NLP! 
인력 수요도 증가 

6. 자연어 처리의 한계점
6-1. 범용적인 툴을 만드는 것이 쉽지 않다. 산업별로 사용하는 언어가 다르기 때문
따라서 표준화 작업이 잘 되어야 합니다. 

그러나, 기술의 한계는 충분히 극복 가능하다.

7. 자연어 처리로 나는 무엇을 할 수 있는가? 
경쟁사 분석 (직감적, 주관적 판단이 아닌 객관적인 판단이 가능하다.)

"""
