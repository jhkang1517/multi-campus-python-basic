# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
bitcoin_url = ('https://crix-api-cdn.upbit.com/v1/crix/trades/days?')
count = 200
params = {
    'code': 'CRIX.UPBIT.KRW-BTC',
    'count': count
}

# %%
resp = requests.get(bitcoin_url, params=params)
resp
# Out:
# <Response [200]>

# %%
resp.json()
# Out:
# [{'code': 'CRIX.UPBIT.KRW-BTC',
#   'tradeDate': '2019-06-04',
#   'tradeDateKst': None,
#   'candleDateTime': '2019-06-04T00:00:00+00:00',
#   'candleDateTimeKst': '2019-06-04T09:00:00+09:00',
#   'tradePrice': 9886000.0,
#   'convertedTradePrice': None,
#   'prevClosingPrice': 9999000.0,
#   'change': 'FALL',
#   'changePrice': 113000.0,
#   'accTradeVolume': 3811.26390428,
#   'accTradePrice': 37575440468.70073,
#   'timestamp': 1559615057232},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'tradeDate': '2019-06-03',
#   'tradeDateKst': None,
#   'candleDateTime': '2019-06-03T00:00:00+00:00',
#   'candleDateTimeKst': '2019-06-03T09:00:00+09:00',
#   'tradePrice': 9999000.0,
#   'convertedTradePrice': None,
#   'prevClosingPrice': 10505000.0,
#   'change': 'FALL',
#   'changePrice': 506000.0,
#   'accTradeVolume': 8905.52487849,
#   'accTradePrice': 91977369426.0219,
#   'timestamp': 1559606399663},
#  {'code': 'CRIX.UPBIT.KRW-BTC',
#   'tradeDate': '2019-06-02',
#   'tradeDateKst': None,
# ...

# %%
json_file = resp.json()

# %%
bitcoin_df = pd.DataFrame(json_file)

# %%
bitcoin_df.to_csv('bitcoin.csv')

# %% [markdown]
# # 4시간짜리 비트코인 데이터

# %%
# bitcoin_4hour_url = ('https://crix-api-cdn.upbit.com/v1/crix/candles/minutes/240?')
# 다시해보세요 지금 오류나요 
time_list = ['240', '60', '30', '10']
bitcoin_4hour_url = ('https://crix-api-cdn.upbit.com/v1/crix/candles/minutes/')

url_list = []
for time in time_list:
    url_list.append(bitcoin_url + time) 
    
print(url_list)
count = 200
params = {
    'code': 'CRIX.UPBIT.KRW-BTC',
    'count': count
}
# Out:
# ['https://crix-api-cdn.upbit.com/v1/crix/trades/days?240', 'https://crix-api-cdn.upbit.com/v1/crix/trades/days?60', 'https://crix-api-cdn.upbit.com/v1/crix/trades/days?30', 'https://crix-api-cdn.upbit.com/v1/crix/trades/days?10']

# %%
resp1 = requests.get(bitcoin_4hour_url)
resp1
# Out:
# <Response [404]>

# %%
resp1.json()
# Out:
# {'error': {'name': 404, 'message': 'No message available'}}

# %%
json_file_1 = resp1.json()

# %%
bitcoin_df.to_csv('bitcoin_4hour.csv')

# %% [markdown]
# # 네이버 블로그 상세페이지 가져오기 실습

# %%
# 들어가기전에
# a탭의 href는 (하이퍼레퍼런스)링크이다.
# iframe안의 src는 원본 소스이다. 후일 이미지도 이를 통해 가져올 수 있다. 

# url을 잘 읽을 줄 아는 것이 중요합니다.

# %%
import requests
from bs4 import BeautifulSoup

# %%
blog_url = "https://search.naver.com/search.naver"
params = dict(
    where='post',
    query="놀란 라이언"
)

# %%
resp = requests.get(blog_url, params=params)
resp
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(resp.content)
blog_list = soup.find_all('li', class_='sh_blog_top')
for blog in blog_list:
    a_tag = blog.find('a')
    link = a_tag['href']
    detail_resp = requests.get(link)
#     print(detail_resp)
    detail_soup = BeautifulSoup(detail_resp.content)
#     print(detail_soup)
    detail_iframe = detail_soup.find('iframe', id="mainFrame")
    
    iframe_src = detail_iframe['src']
    iframe_src = "https://blog.naver.com{}".format(iframe_src)
    print(iframe_src)
#     print(detail_iframe)
    iframe_resp = requests.get(iframe_src)
    iframe_soup = BeautifulSoup(iframe_resp.content)
    blog_post = iframe_soup.find('div', class_="se_doc_viewer se_body_wrap se_theme_transparent")
    print(blog_post)
    break
# Out:
# https://blog.naver.com/PostView.nhn?blogId=jjys9047&logNo=221306678552&from=search&redirect=Log&widgetTypeCall=true&directAccess=false
# <div class="se_doc_viewer se_body_wrap se_theme_transparent" data-docversion="1.0" id="SEDOC-1533733035862-1096909084">
# <div class="se_doc_header_start" id="SEDOC-1533733035862-1096909084_se_doc_header_start"></div>
# <!-- SE_DOC_HEADER_START -->
# <div class="se_viewer_head" id="SEDOC-1533733035862-1096909084_viewer_head"></div>
# <div class="se_component_wrap">
# <div class="se_component se_documentTitle documentTitle_blog is-fill">
# <div class="se_sectionArea is-fill se_align-left">
# <!-- -->
# <div class="blog2_series">
# <a class="pcol2" href="/PostList.nhn?blogId=jjys9047&amp;categoryNo=31&amp;from=postList" onclick="clickcr(this,'pst.category','','',event);">MLB의 17가지불멸의기록</a>
# </div>
# <div class="pcol1">
# <!-- -->
# <!-- SE_DOC_HEADER_TITLE_TOP-->
# ...

# %% [markdown]
# # iframe 실습

# %%
resp = requests.get("https://blog.naver.com/PostView.nhn?blogId=jjys9047&logNo=221306678552&from=search&redirect=Log&widgetTypeCall=true&topReferer=http%3A%2F%2Flocalhost%3A8888%2Fnotebooks%2FDesktop%2F%25EA%25B3%25B5%25EB%25B6%2580%25EC%259E%2590%25EB%25A3%258C%2F%25EC%2588%2598%25EA%25B0%2595%25EC%2583%259D%25EC%259E%2590%25EB%25A3%258C%2Fipynb.ipynb&directAccess=false%22")

# %%
resp
# Out:
# <Response [200]>

# %%
soup3 = BeautifulSoup(resp.content, 'html.parser')
soup3
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="ko">
# <head>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="-1" http-equiv="Expires"/>
# <meta content="always" name="referrer"/>
# <!--[if ie]>
# <style type="text/css">
# html {overflow: scroll; overflow-x: auto;}
# </style>
# <![endif]-->
# <link charset="UTF-8" href="https://ssl.pstatic.net/t.static.blog/mylog/versioning/LayoutTopCommon-252919815_https.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/t.static.blog/mylog/versioning//common/css/music/player-d3fc09e_https.css" rel="stylesheet" type="text/css"/>
# <link href="/favicon.ico?2" rel="shortcut icon" type="image/x-icon">
# <meta content="놀란 라이언의 통산 5714탈삼진" property="og:title"/>
# <meta content="https://blogimgs.pstatic.net/nblog/mylog/post/og_default_image_160610.png" property="og:image"/>
# ...

# %%
post_content = soup3.find('div', class_="se_doc_viewer se_body_wrap se_theme_transparent")
post_content
# Out:
# <div class="se_doc_viewer se_body_wrap se_theme_transparent" data-docversion="1.0" id="SEDOC-1533733035862-1096909084">
# <div class="se_doc_header_start" id="SEDOC-1533733035862-1096909084_se_doc_header_start"></div>
# <!-- SE_DOC_HEADER_START -->
# <div class="se_viewer_head" id="SEDOC-1533733035862-1096909084_viewer_head"></div>
# <div class="se_component_wrap">
# <div class="se_component se_documentTitle documentTitle_blog is-fill">
# <div class="se_sectionArea is-fill se_align-left">
# <!-- -->
# <div class="blog2_series">
# <a class="pcol2" href="/PostList.nhn?blogId=jjys9047&amp;categoryNo=31&amp;from=postList" onclick="clickcr(this,'pst.category','','',event);">MLB의 17가지불멸의기록</a>
# </div>
# <div class="pcol1">
# <!-- -->
# <!-- SE_DOC_HEADER_TITLE_TOP-->
# <div class="se_doc_title_top" id="SEDOC-1533733035862-1096909084_se_doc_title_top"></div>
# <div class="se_editArea">
# <div class="se_viewArea se_ff_nanumgothic se_fs_D2">
# <div class="se_editView se_title">
# ...

# %% [markdown]
# # 블로그 id 찾기

# %%
import requests
from bs4 import BeautifulSoup

# %%
blog_url = "https://search.naver.com/search.naver"
params = dict(
    where='post',
    query="놀란 라이언"
)

# %%
resp = requests.get(blog_url, params=params)
resp
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(resp.content, 'html.parser') # html.poarser는 default 값으로 되어있다.
blog_list = soup.find_all('li', class_='sh_blog_top')
for blog in blog_list:
    a_tag = blog.find('a')
    link = a_tag['href']
    print(link)
    
    #     print(detail_resp)
    # blog_id 가져오기
    break
    # logNo 가져오기
    
    # https://blog.naver.com/PostView.nhn?blogId=jjys9047&logNo=221306678552
# Out:
# https://blog.naver.com/jjys9047?Redirect=Log&logNo=221306678552

# %%
import urllib

# %%
parse_link = urllib.parse.urlparse(link)
parse_link
# Out:
# ParseResult(scheme='https', netloc='blog.naver.com', path='/jjys9047', params='', query='Redirect=Log&logNo=221306678552', fragment='')

# %%
parse_link.path[1:]
# Out:
# 'jjys9047'

# %%
log_str = parse_link.query.split('&')[1]
print(log_str)
# Out:
# logNo=221306678552

# %%
log_id = log_str.split('=')[1]
log_id
# Out:
# '221306678552'

# %%
log_no = parse_link.query

# %%
blogid = parse_link.path[1:]
print(blogid)
log_id
# Out:
# jjys9047
# '221306678552'

# %%
url = "https://blog.naver.com/PostView.nhn"

params = {
    'blogId': blogid,
    'logNo': log_id
}

resp = requests.get(url, params=params)

# %%
resp.url
# Out:
# 'https://blog.naver.com/PostView.nhn?blogId=jjys9047&logNo=221306678552'

# %%
resp
# Out:
# <Response [200]>

# %%
resp.content
# Out:
# b'\r\n\r\n\r\n\r\n\r\n<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">\r\n<html lang="ko">\r\n<head>\r\n<meta http-equiv="Pragma" content="no-cache" />\r\n<meta http-equiv="Expires" content="-1" />\r\n\r\n<meta name="referrer" content="always" />\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n<!--[if ie]>\r\n<style type="text/css">\r\nhtml {overflow: scroll; overflow-x: auto;}\r\n</style>\r\n<![endif]-->\r\n\r\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/t.static.blog/mylog/versioning/LayoutTopCommon-252919815_https.css" charset="UTF-8" />\r\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/t.static.blog/mylog/versioning//common/css/music/player-d3fc09e_https.css">\r\n\r\n<link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?2" />\r\n\n\n\n\n\n \n\n\t\n\t\t<meta property="og:title" content="\xeb\x86\x80\xeb\x9e\x80 \xeb\x9d\xbc\xec\x9d\xb4\xec\x96\xb8\xec\x9d\x98 \xed\x86\xb5\xec\x82\xb0
# ...
