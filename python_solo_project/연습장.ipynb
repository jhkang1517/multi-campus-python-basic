# %%
# import random
# card = ["미샤", "킁킁이", "레호구"] 
# computer = random.randint(1,3)

# # 
# if computer in [1, 2, 3]:
#     print('your card is %s'% (card[computer-1]))
    
# else:
#     print("종료")

# %%
import Gibson_Crawling_Moduel

# %%
Gibson_Crawling_Moduel.intro
# Out:
# "Les-Paul, SG, ES, Acoustic, Designer, Bass 를 'crl.run( )'안에 입력하세요.\n입력한 값에 대한 깁슨 홈페이지에 있는 모든 깁슨 모델을 제공합니다."

# %%
Gibson_Crawling_Moduel.maker
# Out:
# 'jhkang1517@gmail.com'

# %%
dir(Gibson_Crawling_Moduel)
# Out:
# ['BASE_DIR',
#  'BeautifulSoup',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'crl',
#  'intro',
#  'maker',
#  'os',
#  'pd',
#  'pprint',
#  'requests']

# %%
Gibson_Crawling_Moduel.crl.run('Acoustic')
# Out:
# 총 52 개의 결과물이 있습니다.
# Gibson Accessory Kit의 주소는 https://www.gibson.com/Gear/Accessories/G-CAREKIT1 입니다.
# [{'link': 'https://www.gibson.com/Guitar/ACC3NY964/125th-Anniversary-J-45',
#   'name': '125th Anniversary J-45',
#   'price': '$4,999.00',
#   'Body': ['Shape\nRound Shoulder',
#    'Top Material\nLutz Spruce',
#    'Back Material\nFigured Mahogany',
#    'Side Material\nFigured Mahogany',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nSlim Taper',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Nut Width\n1.725" / 43.82mm',
#    'Inlays\nMother-of-pearl dots, 125th headstock inlay'],
#   'Hardware': ['Tuners\nGotoh open back',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nLimited',
#    'Pick Guard\nTear Drop',
#    'Saddle Material\nTusq',
#    'Bridge\nTraditional belly up, rosewood',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume and tone controls in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCVID935/125th-Anniversary-Hummingbird',
#   'name': '125th Anniversary Hummingbird',
#   'price': '$5,499.00',
#   'Body': ['Shape\nSquare Shoulder',
#    'Top Material\nLutz Spruce',
#    'Back Material\nFigured Mahogany',
#    'Side Material\nFigured Mahogany',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, multi-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nRound',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Nut Width\n1.725" / 43.82mm',
#    'Inlays\nMother-of-pearl parallelograms, 125th headstock inlay'],
#   'Hardware': ['Tuners\nGrover Keystone',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nLimited',
#    'Pick Guard\nHummingbird, stamped tortise',
#    'Saddle Material\nTusq',
#    'Bridge\nTraditional belly up, rosewood',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume and Tone controls in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACC5VI857/125th-Anniversary-SJ-200',
#   'name': '125th Anniversary SJ-200',
#   'price': '$6,149.00',
#   'Body': ['Shape\nSJ-200',
#    'Top Material\nLutz Spruce',
#    'Back Material\nQuilted Maple',
#    'Side Material\nQuilted Maple',
#    'Bracing\nTraditional hand scalloped X-bracing',
#    'Binding\nMulti-ply top, multi-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\n2-piece maple',
#    'Neck Profile\nRound',
#    'Scale Length\n25.5" / 64.77cm',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Nut Width\n1.725" / 43.82mm',
#    'Inlays\nMother-of-pearl Graduated Crowns, 125th headstock inlay'],
#   'Hardware': ['Tuners\nGrover Imperials',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nLimited',
#    'Pick Guard\nSJ-200, stamped tortise, Mother-of-pearl dots',
#    'Saddle Material\nTusq',
#    'Bridge\nSJ-200, Moustache, Rosewood',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume and Tone controls in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCDUQ766/J-45-Walnut-M-Antique-Natural',
#   'name': 'J-45 Walnut M Antique Natural',
#   'price': '$1,799.00',
#   'Body': ['Shape\nAcoustic',
#    'Top Material\nSitka spruce',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nTwo-piece maple',
#    'Neck Profile\nAdvanced Response',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n16" / 406.4mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Nut Width\n1.725" / 43.82mm',
#    'Inlays\nMother-of-pearl dots'],
#   'Hardware': ['Tuners\nMini Grover Rotomatic w/ kidney buttons',
#    'Tuner Plating\nNickel',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nTear drop',
#    'Saddle Material\nTusq',
#    'Bridge\nTraditional belly up',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume control in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACC7JP801/J-45-Standard',
#   'name': 'J-45 Standard',
#   'price': '$2,749.00',
#   'Body': ['Shape\nJumbo',
#    'Top Material\nSitka Spruce',
#    'Back Material\nMahogany',
#    'Side Material\nMahogany',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nSlim Taper',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nBlack',
#    'Nut Width\n1.725" / 43.82mm',
#    'Inlays\nMother-of-pearl dots'],
#   'Hardware': ['Tuners\nGrover Rotomatics w/ Kidney Buttons',
#    'Tuner Plating\nNickel',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nTear Drop',
#    'Saddle Material\nTusq',
#    'Bridge\nTraditional belly up, Rosewood',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\n1 Volume, 1 T'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCAQJ999/J-45-Rosewood-M',
#   'name': 'J-45 Rosewood M',
#   'price': '$2,199.00',
#   'Body': ['Shape\nAcoustic',
#    'Top Material\nSitka spruce',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nAdvanced Response',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n16" / 406.4mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Nut Width\n1.725" / 43.82mm',
#    'Inlays\nMother-of-pearl Single Parallelogram'],
#   'Hardware': ['Tuners\nMini Grover Rotomatic',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nTear Drop',
#    'Saddle Material\nTusq',
#    'Bridge\nTraditional belly up',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume and Tone controls in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCVFB499/Hummingbird-M-Mahogany',
#   'name': 'Hummingbird M Mahogany',
#   'price': '$2,499.00',
#   'Body': ['Shape\nSquare Shoulder',
#    'Top Material\nSitka spruce',
#    'Back Material\nMahogany',
#    'Side Material\nMahogany',
#    'Bracing\nTraditional hand-scalloped Advanced X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nAdvanced Response',
#    'Scale Length\n25.5" / 64.77cm',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n16" / 406.4mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Nut Width\n1.725" / 43.815mm',
#    'Inlays\nMother-of-pearl dots'],
#   'Hardware': ['Tuners\nMini Grover Rotomatic',
#    'Tuner Plating\nNickel',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nHummingbird Avant Garde',
#    'Saddle Material\nTusq',
#    'Bridge\nTraditional belly up, Rosewood',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\n1 Volum'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACC4YC313/J-45-Mahogany-M',
#   'name': 'J-45 Mahogany M',
#   'price': '$1,999.00',
#   'Body': ['Shape\nJumbo',
#    'Top Material\nSitka spruce',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nAdvanced Response',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n16" / 406.4mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Nut Width\n1.725" / 43.82mm',
#    'Inlays\nMother-of-pearl dots'],
#   'Hardware': ['Tuners\nMini Grover Rotomatic',
#    'Tuner Plating\nNickel',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nTear Drop',
#    'Saddle Material\nTusq',
#    'Bridge\nTraditional belly up',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume control in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCT98899/J-45-Chroma-Modern',
#   'name': 'J-45 Chroma Modern',
#   'price': '$3,999.00',
#   'Body': ['Shape\nJ-45',
#    'Top Material\nSitka spruce',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nTwo-piece maple',
#    'Neck Profile\nAdvanced Response',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n16" / 406.4mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Nut Width\n1.725" / 43.82mm',
#    'Inlays\nMother-of-pearl Split Blo'],
#   'Hardware': ['Tuners\nMini Grover Rotomatic',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nTear Drop',
#    'Saddle Material\nTusq',
#    'Bridge\nTraditional belly up',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nConvenient soundhole-located'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACC6HS545/J-45-Walnut-Modern',
#   'name': 'J-45 Walnut Modern',
#   'price': '$1,999.00',
#   'Body': ['Shape\nJumbo',
#    'Top Material\nSitka spruce',
#    'Back Material\nWalnut',
#    'Side Material\nWalnut',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nTwo-piece maple',
#    'Neck Profile\nAdvanced Response',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n16" / 406.4mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Nut Width\n1.725" / 43.82mm',
#    'Inlays\nMother-of-pearl dots'],
#   'Hardware': ['Tuners\nMini Grover Rotomatic',
#    'Tuner Plating\nNickel',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nTear drop',
#    'Saddle Material\nTusq',
#    'Bridge\nTraditional belly up, Richlite',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\n1 Volum'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCJ3Q287/Hummingbird-M-Rosewood',
#   'name': 'Hummingbird M Rosewood ',
#   'price': '$2,699.00',
#   'Body': ['Shape\nSquare Shoulder',
#    'Top Material\nSitka spruce',
#    'Back Material\nRosewood',
#    'Side Material\nRosewood',
#    'Bracing\nTraditional hand-scalloped Advanced X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nAdvanced Response',
#    'Scale Length\n25.5" / 64.77cm',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n16" / 406.4mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Nut Width\n1.725" / 43.815mm',
#    'Inlays\nMother-of-pearl Single Parallelogram'],
#   'Hardware': ['Tuners\nMini Grover Rotomatic',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nHummingbird Avant Garde',
#    'Saddle Material\nTusq',
#    'Bridge\nTraditional belly up',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume and Tone controls in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACC37L866/J-45-Vintage',
#   'name': 'J-45 Vintage',
#   'price': '$4,749.00',
#   'Body': ['Shape\nJumbo',
#    'Top Material\nThermally Aged Red Spruce',
#    'Back Material\nMahogany',
#    'Side Material\nMahogany',
#    'Bracing\nTraditional hand-scalloped Advacned X-bracing, with hide glue',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nThin Finish Nitrocellulose, VOS'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nVintage Round',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nBone',
#    'Nut Width\n1.725" / 43.82mm',
#    'Inlays\nMother-of-pearl Dots'],
#   'Hardware': ['Tuners\nGotoh Relic White Button',
#    'Tuner Plating\nAged Nickel',
#    'Truss Rod Cover\nBlack',
#    'Pick Guard\nTear drop',
#    'Saddle Material\nBone',
#    'Bridge\nTraditional belly up',
#    'Bridge Pins\nBon'],
#   'Electronics': [''],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACC5JY735/J-45-Sustainable',
#   'name': 'J-45 Sustainable',
#   'price': '$2,199.00',
#   'Body': ['Shape\nJumbo',
#    'Top Material\nSitka spruce',
#    'Back Material\nWalnut',
#    'Side Material\nWalnut',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nHand rubbed wax'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nSlim Taper',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Nut Width\n1.725" / 43.815mm',
#    'Inlays\nDiamonds and arrows, wood'],
#   'Hardware': ['Tuners\nGrover Rotomatics w/ kidney buttons',
#    'Tuner Plating\nNickel',
#    'Truss Rod Cover\nWalnut',
#    'Pick Guard\nTear drop, walnut',
#    'Saddle Material\nTusq',
#    'Bridge\nTraditional belly up',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\n1 Volume, 1 T'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCECN54/J-45-Standard-Heritage-Cherry-Sunburst',
#   'name': 'J-45 Standard Heritage Cherry Sunburst',
#   'price': '$2,749.00',
#   'Body': ['Shape\nJumbo',
#    'Top Material\nSitka Spruce',
#    'Back Material\nMahogany',
#    'Side Material\nMahogany',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nSlim Taper',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nBlack',
#    'Inlays\nMother-of-pearl dots'],
#   'Hardware': ['Tuners\nGrover Rotomatics',
#    'Tuner Plating\nNickel',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nTear Drop',
#    'Saddle Material\nTusq',
#    'Bridge\nTraditional belly up',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume and Tone controls in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCC6T340/J-45-Deluxe',
#   'name': 'J-45 Deluxe',
#   'price': '$3,699.00',
#   'Body': ['Shape\nJumbo',
#    'Top Material\nSitka Spruce',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-colored rope top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nSlim Taper',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nGold',
#    'Nut Material\nBone',
#    'Nut Width\n1.725" / 43.815mm',
#    'Inlays\nMother-of-pearl split diamond with brass border'],
#   'Hardware': ['Tuners\nGrover Rotomatic w/ kidney buttons',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nDeluxe',
#    'Pick Guard\nTear drop with gold border',
#    'Saddle Material\nBone',
#    'Bridge\nTraditional belly up',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume and Tone controls in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACC9E9481/J-45-Cutaway',
#   'name': 'J-45 Cutaway',
#   'price': '$2,849.00',
#   'Body': ['Shape\nJumbo',
#    'Top Material\nSitka Spruce',
#    'Back Material\nMahogany',
#    'Side Material\nMahogany',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nSlim Taper',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nBlack',
#    'Nut Width\n1.725" / 43.82mm',
#    'Inlays\nMother-of-pearl dots'],
#   'Hardware': ['Tuners\nGrover Rotomatics w/ kidney buttons',
#    'Tuner Plating\nNickel',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nTear Drop',
#    'Saddle Material\nTusq',
#    'Bridge\nTraditional belly up',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume and Tone controls in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCUEW899/Parlor-Walnut-M',
#   'name': 'Parlor Walnut M',
#   'price': '$1,799.00',
#   'Body': ['Shape\nParlor',
#    'Top Material\nSitka spruce',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nTwo-piece maple',
#    'Neck Profile\nAdvanced Response',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n16" / 406.4mm',
#    'Number of Frets\n19',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Nut Width\n1.725" / 43.82mm',
#    'Inlays\nMother-of-pearl dots'],
#   'Hardware': ['Tuners\nMini Grover Rotomatic',
#    'Tuner Plating\nNickel',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nParlor Avant Garde',
#    'Saddle Material\nTusq',
#    'Bridge\nTraditional belly up',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume control in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCZSS791/Parlor-Rosewood-Modern',
#   'name': 'Parlor Rosewood Modern',
#   'price': '$2,199.00',
#   'Body': ['Shape\nParlor',
#    'Top Material\nSitka spruce',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nAdvanced Response',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n16" / 406.4mm',
#    'Number of Frets\n19',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Nut Width\n1.725" / 43.82mm',
#    'Inlays\nMother-of-pearl Single Parallelogram'],
#   'Hardware': ['Tuners\nMini Grover Rotomatic',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nParlor Avant Garde',
#    'Saddle Material\nTusq',
#    'Bridge\nTraditional Belly up',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume and Tone controls in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACC44J939/Parlor-Mahogany-M',
#   'name': 'Parlor Mahogany M',
#   'price': '$1,999.00',
#   'Body': ['Shape\nAcoustic',
#    'Top Material\nSitka spruce',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nAdvanced Response',
#    'Scale Length\n24.753" / 62.873cm',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n16" / 406.4mm',
#    'Number of Frets\n19',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Nut Width\n1.725" / 43.82mm',
#    'Inlays\nMother-of-pearl dots'],
#   'Hardware': ['Tuners\nMini Grover Rotomatic',
#    'Tuner Plating\nNickel',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nParlor Avant Garde',
#    'Saddle Material\nTusq',
#    'Bridge\nTraditional belly up',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume control in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCF5P76/Parlor-Chroma-M',
#   'name': 'Parlor Chroma M',
#   'price': '$3,999.00',
#   'Body': ['Shape\nAcoustics',
#    'Top Material\nSitka Spruce',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nTwo-piece maple',
#    'Neck Profile\nAdvanced Response',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n16" / 406.4mm',
#    'Number of Frets\n19',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Nut Width\n1.725" / 43.82mm',
#    'Inlays\nMother-of-pearl Split Blo'],
#   'Hardware': ['Tuners\nMini Grover Rotomatic',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nParlor',
#    'Saddle Material\nTusq',
#    'Bridge\nTraditional belly up',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nControls mounted in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCDR2316/Hummingbird-Walnut-M',
#   'name': 'Hummingbird Walnut M',
#   'price': '$1,999.00',
#   'Body': ['Shape\nAcoustic',
#    'Top Material\nSitka spruce',
#    'Bracing\nTraditional hand-scalloped Advanced X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nTwo-piece maple',
#    'Neck Profile\nAdvanced Response',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n16" / 406.4mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Nut Width\n1.725" / 43.82mm',
#    'Inlays\nMother-of-pearl dots'],
#   'Hardware': ['Tuners\nMini Grover Rotomatic',
#    'Tuner Plating\nNickel',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nHummingbird Avant Garde',
#    'Saddle Material\nTusq',
#    'Bridge\nTraditional belly up',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume control in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCGZU118/Doves-in-Flight',
#   'name': 'Doves in Flight',
#   'price': '$7,499.00',
#   'Body': ['Shape\nSquare Shoulder',
#    'Top Material\nSitka spruce',
#    'Back Material\nFlame maple',
#    'Side Material\nFlame maple',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, multi-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nThree-piece maple',
#    'Neck Profile\nRound',
#    'Scale Length\n25.503" / 64.778cm',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nBone',
#    'Nut Width\n1.575" / 40mm',
#    'Inlays\nDoves in Flight'],
#   'Hardware': ['Tuners\nGrover with engraved Keystone',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nDove, mother-of-pearl inlay',
#    'Saddle Material\nBone',
#    'Bridge\nDove',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nN/a'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCNXQ460/Songwriter',
#   'name': 'Songwriter',
#   'price': '$2,999.00',
#   'Body': ['Shape\nSquare Shoulder',
#    'Top Material\nSitka spruce',
#    'Back Material\nRosewood',
#    'Side Material\nRosewood',
#    'Bracing\nTraditional hand-scalloped Advanced X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nRound',
#    'Scale Length\n25.5" / 64.77cm',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Inlays\nMother-of-pearl Parallelogram'],
#   'Hardware': ['Tuners\nGrover Rotomatic w/ Kidney Buttons',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nCustom Line',
#    'Saddle Material\nTusq',
#    'Bridge\nCustom Line',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume and Tone controls in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCVPP944/Songwriter-12-String',
#   'name': 'Songwriter 12-String',
#   'price': '$3,299.00',
#   'Body': ['Shape\nSquare Shoulder',
#    'Top Material\nSitka spruce',
#    'Back Material\nRosewood',
#    'Side Material\nRosewood',
#    'Bracing\nTraditional hand-scalloped Advanced X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nRound',
#    'Scale Length\n25.5" / 64.77cm',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nBone',
#    'Nut Width\n1.875" / 47.625mm',
#    'Inlays\nMother-of-pearl Parallelogram'],
#   'Hardware': ['Tuners\nMini Grover Rotomatic',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nCustom Line',
#    'Saddle Material\nBone',
#    'Bridge\nCustom Line',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume and Tone controls in soundh'],
#   'Miscellaneous': ['Strings\n12-string',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACC73T218/SJ-200-Vintage',
#   'name': 'SJ-200 Vintage',
#   'price': '$6,499.00',
#   'Body': ['Shape\nSuper Jumbo',
#    'Top Material\nThermally Aged Red Spruce',
#    'Back Material\nFlame Maple',
#    'Side Material\nFlame Maple',
#    'Bracing\nTraditional hand-scalloped X-bracing, with hide glue',
#    'Binding\nMulti-ply top, multi-ply back',
#    'Finish\nThin Finish Nitrocellulose, VOS'],
#   'Neck': ['Material\nTwo-piece maple',
#    'Neck Profile\nRound',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nBone',
#    'Nut Width\n1.725" / 43.815mm',
#    'Inlays\nMother-of-pearl Graduated Crowns'],
#   'Hardware': ['Tuners\nGotoh Relic',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nBlack with wide white',
#    'Pick Guard\nTraditional SJ-200',
#    'Saddle Material\nBone',
#    'Bridge\nFour bar SJ-200 Moustache™',
#    'Bridge Pins\nBon'],
#   'Electronics': [''],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCA9P349/SJ-200-Studio',
#   'name': 'SJ-200 Studio',
#   'price': '$3,099.00',
#   'Body': ['Shape\nSuper Jumbo',
#    'Top Material\nSitka spruce',
#    'Back Material\nWalnut',
#    'Side Material\nWalnut',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nAdvanced Response',
#    'Scale Length\n25.5" / 64.77cm',
#    'Fingerboard Material\nWalnut',
#    'Fingerboard Radius\n16" / 406.4mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Nut Width\n1.725" / 43.82mm',
#    'Inlays\nMother-of-pearl Graduated Crowns'],
#   'Hardware': ['Tuners\nGrover Rotomatic w/ kidney buttons',
#    'Tuner Plating\nNickel',
#    'Truss Rod Cover\nStudio',
#    'Pick Guard\nSJ-200, no stamp',
#    'Saddle Material\nTusq',
#    'Bridge\nMoustache™',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume and Tone controls in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCH87632/L-00-Sustainable',
#   'name': 'L-00 Sustainable',
#   'price': '$2,099.00',
#   'Body': ['Shape\nSmall Body',
#    'Top Material\nSitka spruce',
#    'Back Material\nWalnut',
#    'Side Material\nWalnut',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nSingle-ply top, single-ply back',
#    'Finish\nHand rubbed Wax'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nSlim Taper',
#    'Scale Length\n24.747" / 62.858cm',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n19',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Nut Width\n1.725" / 43.82mm',
#    'Inlays\nDiamonds and Arrows, wood'],
#   'Hardware': ['Tuners\nMini Grover Rotomatic',
#    'Tuner Plating\nNickel',
#    'Truss Rod Cover\nWalnut',
#    'Pick Guard\nL-00, Walnut',
#    'Saddle Material\nTusq',
#    'Bridge\nRectangular, Richlite',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\n1 Volume, 1 T'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCDNP224/L-00-Studio',
#   'name': 'L-00 Studio',
#   'price': '$1,499.00',
#   'Body': ['Shape\nSmall Body',
#    'Top Material\nSitka spruce',
#    'Back Material\nWalnut',
#    'Side Material\nWalnut',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nAdvanced Response',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nWalnut',
#    'Fingerboard Radius\n16" / 406.4mm',
#    'Number of Frets\n19',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Inlays\nMother-of-pearl dots'],
#   'Hardware': ['Tuners\nMini Grover Rotomatic',
#    'Tuner Plating\nNickel',
#    'Truss Rod Cover\nStudio',
#    'Pick Guard\nL-00',
#    'Saddle Material\nTusq',
#    'Bridge\nRectangular closed slot',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume and Tone controls in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCSMC348/L-00-Standard',
#   'name': 'L-00 Standard',
#   'price': '$2,699.00',
#   'Body': ['Shape\nSmall Body',
#    'Top Material\nSitka spruce',
#    'Back Material\nMahogany',
#    'Side Material\nMahogany',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nSingle-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nSlim Taper',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n19',
#    'Frets\nStandard',
#    'Nut Material\nBlack',
#    'Inlays\nMother-of-pearl dots'],
#   'Hardware': ['Tuners\nMini Grover Rotomatic',
#    'Tuner Plating\nNickel',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nL-00',
#    'Saddle Material\nTusq',
#    'Bridge\nRectangle, closed slot',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume and Tone controls in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACC2JI4/Parlor-M-Rosewood',
#   'name': 'Parlor M Rosewood ',
#   'price': '$2,399.00',
#   'Body': ['Shape\nSmall Body',
#    'Top Material\nSitka spruce',
#    'Back Material\nRosewood',
#    'Side Material\nRosewood',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nAdvanced Response',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n16" / 406.4mm',
#    'Number of Frets\n19',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Nut Width\n1.725" / 43.815mm',
#    'Inlays\nMother-of-pearl Single Parallelogram'],
#   'Hardware': ['Tuners\nMini Grover Rotomatic',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nParlor Avant Garde',
#    'Saddle Material\nTusq',
#    'Bridge\nTraditional Belly up',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume and Tone controls in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCAMG993/L-00-Deluxe',
#   'name': 'L-00 Deluxe',
#   'price': '$3,499.00',
#   'Body': ['Shape\nSmall Body',
#    'Top Material\nSitka Spruce',
#    'Back Material\nRosewood',
#    'Side Material\nRosewood',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-colored rope top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nSlim Taper',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n19',
#    'Frets\nGold',
#    'Nut Material\nBone',
#    'Nut Width\n1.725" / 43.815mm',
#    'Inlays\nMother-of-pearl split diamond with brass border'],
#   'Hardware': ['Tuners\nMini Grover Rotomatic',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nDeluxe',
#    'Saddle Material\nBone',
#    'Bridge\nRectangular closed slot',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume and Tone controls in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACC59H78/J-185-Vintage',
#   'name': 'J-185 Vintage',
#   'price': '$4,999.00',
#   'Body': ['Shape\nJumbo',
#    'Top Material\nThermally Aged Sitka Spruce',
#    'Back Material\nFlame Maple',
#    'Side Material\nFlame Maple',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, multi-ply back',
#    'Finish\nThin Finish Nitrocellulose, VOS'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nSlim Taper',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nBone',
#    'Nut Width\n1.725" / 43.815mm',
#    'Inlays\nMother-of-pearl Parallelograms'],
#   'Hardware': ['Tuners\nGotoh Relic',
#    'Tuner Plating\nAged Gold',
#    'Truss Rod Cover\nBlack',
#    'Pick Guard\nJ-185',
#    'Saddle Material\nBone',
#    'Bridge\nBelly up, open slot',
#    'Bridge Pins\nBon'],
#   'Electronics': [''],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACC3YP77/J-15-Antique-Natural',
#   'name': 'J-15 Antique Natural',
#   'price': '$1,749.00',
#   'Body': ['Shape\nJumbo',
#    'Top Material\nSitka spruce',
#    'Back Material\nWalnut',
#    'Side Material\nWalnut',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\n2-piece maple',
#    'Neck Profile\nSlim Taper',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nWalnut',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Inlays\nMother-of-pearl dots'],
#   'Hardware': ['Tuners\nMini Grover Rotomatic',
#    'Tuner Plating\nNickel',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nTear Drop',
#    'Saddle Material\nTusq',
#    'Bridge\nRectangular, closed slot, Walnut',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\n1 Volum'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCNJZ570/Hummingbird-Vintage',
#   'name': 'Hummingbird Vintage',
#   'price': '$5,049.00',
#   'Body': ['Shape\nSquare Shoulder',
#    'Top Material\nThermally Aged Sitka spruce',
#    'Back Material\nMahogany',
#    'Side Material\nMahogany',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, multi-ply back',
#    'Finish\nThin Finish Nitrocellulose, VOS'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nRound',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nBone',
#    'Nut Width\n1.725" / 43.815mm',
#    'Inlays\nMother-of-pearl Parallelograms'],
#   'Hardware': ['Tuners\nGotoh Relic',
#    'Tuner Plating\nAged Gold',
#    'Truss Rod Cover\nHummingbird',
#    'Pick Guard\nCasted Hummingbird',
#    'Saddle Material\nBone',
#    'Bridge\nTraditional belly up',
#    'Bridge Pins\nBon'],
#   'Electronics': [''],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCA5Z486/Hummingbird-Sustainable',
#   'name': 'Hummingbird Sustainable',
#   'price': '$2,499.00',
#   'Body': ['Shape\nSquare Shoulder',
#    'Top Material\nSitka spruce',
#    'Back Material\n Walnut',
#    'Side Material\n Walnut',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, multi-ply back',
#    'Finish\nHand rubbed wax'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nRound',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Nut Width\n1.725" / 43.815mm',
#    'Inlays\nDiamonds and arrow, wood'],
#   'Hardware': ['Tuners\nGrover Rotomatic w/ kidney buttons',
#    'Tuner Plating\nNickel',
#    'Truss Rod Cover\nWalnut',
#    'Pick Guard\nWalnut',
#    'Saddle Material\nTusq',
#    'Bridge\nTraditional belly up',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\n1 Volume, 1 T'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCQKN561/Hummingbird-Studio',
#   'name': 'Hummingbird Studio',
#   'price': '$1,999.00',
#   'Body': ['Shape\nAcoustic',
#    'Top Material\nSitka spruce',
#    'Back Material\nWalnut',
#    'Side Material\nWalnut',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nAdvanced Response',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nWalnut',
#    'Fingerboard Radius\n16" / 406.4mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Inlays\nMother-of-pearl Parallelograms'],
#   'Hardware': ['Tuners\nGrover Rotomatic w/ kidney buttons',
#    'Tuner Plating\nNickel',
#    'Truss Rod Cover\nStudio',
#    'Pick Guard\nHummingbird, no stamp',
#    'Saddle Material\nTusq',
#    'Bridge\nTraditional belly up',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume and Tone controls in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCA4V477/Hummingbird-Deluxe',
#   'name': 'Hummingbird Deluxe',
#   'price': '$4,499.00',
#   'Body': ['Shape\nSquare Shoulder',
#    'Top Material\nSitka Spruce',
#    'Back Material\nRosewood',
#    'Side Material\nRosewood',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, multi-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nRound',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nGold',
#    'Nut Material\nBone',
#    'Nut Width\n1.725" / 43.82mm',
#    'Inlays\nMother-of-pearl Parallelograms with brass border'],
#   'Hardware': ['Tuners\nGrover Rotomatic',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nDeluxe',
#    'Pick Guard\nHummingbird with gold',
#    'Saddle Material\nBone',
#    'Bridge\nTraditional belly up',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume and Tone controls in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCISQ773/30th-Anniversary-Starburst',
#   'name': '30th Anniversary Starburst',
#   'price': '$6,599.00',
#   'Body': ['Shape\nJumbo',
#    'Top Material\nQuilt Maple',
#    'Back Material\nFlame Maple',
#    'Side Material\nFlame Maple',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, multi-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nThree-piece maple',
#    'Neck Profile\nRound',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nBone',
#    'Nut Width\n1.725" / 43.815mm',
#    'Inlays\nMother-of-pearl Starburst'],
#   'Hardware': ['Tuners\nGrover Rotomatic w/ kidney buttons',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nNone',
#    'Saddle Material\nBone',
#    'Bridge\nCustom Line',
#    'Bridge Pins\nBon'],
#   'Electronics': ['Controls\nVolume and Tone controls in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCLGZ832/30th-Anniversary-Montana-Gold',
#   'name': '30th Anniversary Montana Gold',
#   'price': '$6,599.00',
#   'Body': ['Shape\nSuper Jumbo',
#    'Top Material\nSitka spruce',
#    'Back Material\nQuilt maple',
#    'Side Material\nQuilt maple',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, multi-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\ntwo-piece maple',
#    'Neck Profile\nRound',
#    'Scale Length\n25.5" / 64.77cm',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nBone',
#    'Nut Width\n1.725" / 43.815mm',
#    'Inlays\nMother-of-pearl blo'],
#   'Hardware': ['Tuners\nGrover Imperials',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nSJ-200 with Montana Gold logo and gold wheat',
#    'Saddle Material\nBone',
#    'Bridge\nFour bar Moustache™',
#    'Bridge Pins\nBon'],
#   'Electronics': ['Controls\nVolume and Tone controls in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCAV7873/30th-Anniversary-J-2000',
#   'name': '30th Anniversary J-2000',
#   'price': '$6,599.00',
#   'Body': ['Shape\nJumbo',
#    'Top Material\nSitka spruce',
#    'Back Material\nRosewood',
#    'Side Material\nRosewood',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top with abalone, multi-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nRound',
#    'Scale Length\n25.5" / 64.77cm',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nBone',
#    'Nut Width\n1.725" / 43.815mm',
#    'Inlays\nAbalone Autumn Leaf'],
#   'Hardware': ['Tuners\nGrover Keystone',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nCustom Line',
#    'Saddle Material\nBone',
#    'Bridge\nCustom Line',
#    'Bridge Pins\nTusq with abalone dots'],
#   'Electronics': ['Controls\nVolume and Tone controls in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCRTL949/30th-Anniversary-CL-50',
#   'name': '30th Anniversary CL-50',
#   'price': '$6,599.00',
#   'Body': ['Shape\nSquare Shoulder',
#    'Top Material\nBearclaw Englemann Spruce',
#    'Back Material\nRosewood',
#    'Side Material\nRosewood',
#    'Bracing\nCustom hand-scalloped Advanced X-bracing',
#    'Binding\nMulti-ply top, multi-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nRound',
#    'Scale Length\n25.5" / 64.77cm',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nBone',
#    'Nut Width\n1.725" / 43.815mm',
#    'Inlays\nMother-of-pearl Autumn Leaf'],
#   'Hardware': ['Tuners\nGrover Rotomatic w/ kidney buttons',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nB/W',
#    "Pick Guard\n0.060'' Custom Line",
#    'Saddle Material\nBone',
#    'Bridge\nCustom Line',
#    'Bridge Pins\nTusq with abalone dots'],
#   'Electronics': ['Controls\nVolume and Tone controls in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCJXC990/SJ-200-Deluxe',
#   'name': 'SJ-200 Deluxe',
#   'price': '$5,999.00',
#   'Body': ['Shape\nSuper Jumbo',
#    'Top Material\nSitka Spruce',
#    'Back Material\nRosewood',
#    'Side Material\nRosewood',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-colored rope top, multi-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nRound',
#    'Scale Length\n25.5" / 64.77cm',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nGold',
#    'Nut Material\nBone',
#    'Nut Width\n1.725" / 43.815mm',
#    'Inlays\nMother-of-pearl Crowns with brass border'],
#   'Hardware': ['Tuners\nGrover Rotomatic w/ kidney buttons',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nDeluxe',
#    'Pick Guard\nSJ-200 with gold and Mother-of-pearl dots',
#    'Saddle Material\nBone',
#    'Bridge\nSJ-200 Moustache™',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume and Tone controls in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCBUQ665/SJ-200-Standard',
#   'name': 'SJ-200 Standard ',
#   'price': '$5,049.00',
#   'Body': ['Shape\nSuper Jumbo',
#    'Top Material\nSitka Spruce',
#    'Back Material\nFlame Maple',
#    'Side Material\nFlame Maple',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, multi-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nTwo-piece maple',
#    'Neck Profile\nRound',
#    'Scale Length\n25.5" / 64.77cm',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Inlays\nMother-of-pearl Graduated Crowns'],
#   'Hardware': ['Tuners\nGrover Rotomatics w/ Kidney Buttons',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nSJ-200',
#    'Saddle Material\nTusq',
#    'Bridge\nSJ-200 Moustache™, Rosewood',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume, Mix, Phase, Battery Check'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCE3P829/Hummingbird-Rosewood-M',
#   'name': 'Hummingbird Rosewood M',
#   'price': '$2,499.00',
#   'Body': ['Shape\nAcoustic',
#    'Top Material\nSitka spruce',
#    'Bracing\nTraditional hand-scalloped Advanced X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nAdvanced Response',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n16" / 406.4mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Nut Width\n1.725" / 43.82mm',
#    'Inlays\nMother-of-pearl Single Parallelogram'],
#   'Hardware': ['Tuners\nMini Grover Rotomatic',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nHummingbird Avant Garde',
#    'Saddle Material\nTusq',
#    'Bridge\nTraditional belly up',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nVolume and Tone controls in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCQBA896/Hummingbird',
#   'name': 'Hummingbird ',
#   'price': '$3,849.00',
#   'Body': ['Shape\nSquare Shoulder',
#    'Top Material\nSitka Spruce',
#    'Back Material\nMahogany',
#    'Side Material\nMahogany',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, multi-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nRound',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Nut Width\n1.725" / 43.82mm',
#    'Inlays\nMother-of-pearl Parallelograms'],
#   'Hardware': ['Tuners\nGrover Rotomatic w/ Kidney Buttons',
#    'Tuner Plating\nNickel',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nHummingbird',
#    'Saddle Material\nTusq',
#    'Bridge\nTraditional belly up, Rosewood',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\n1 Volume, 1 T'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCXV8819/J-15-Walnut-Burst',
#   'name': 'J-15 Walnut Burst',
#   'price': '$1,949.00',
#   'Body': ['Shape\nAcoustic',
#    'Top Material\nSitka spruce',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\n2-piece maple',
#    'Neck Profile\nSlim Taper',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nWalnut',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Nut Width\n1.725" / 43.82mm',
#    'Inlays\nMother-of-pearl dots'],
#   'Hardware': ['Tuners\nMini Grover Rotomatic',
#    'Tuner Plating\nNickel',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nTear Drop',
#    'Saddle Material\nTusq',
#    'Bridge\nRectangular, closed slot, Walnut',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\n1 Volum'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCICQ66/J-45-Studio',
#   'name': 'J-45 Studio ',
#   'price': '$1,699.00',
#   'Body': ['Shape\nJumbo',
#    'Top Material\nSitka spruce',
#    'Back Material\nWalnut',
#    'Side Material\nWalnut',
#    'Bracing\nTraditional hand-scalloped X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nAdvanced Response',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nWalnut',
#    'Fingerboard Radius\n16" / 406.4mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Nut Width\n1.725" / 43.82mm',
#    'Inlays\nMother-of-pearl dots'],
#   'Hardware': ['Tuners\nGrover Rotomatic w/ Kidney buttons',
#    'Tuner Plating\nNickel',
#    'Truss Rod Cover\nStudio',
#    'Pick Guard\nTear Drop',
#    'Saddle Material\nTusq',
#    'Bridge\nTraditional belly up, Walnut',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\n1 Volume, 1 T'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCXW2802/Songwriter-Cutaway',
#   'name': 'Songwriter Cutaway ',
#   'price': '$3,299.00',
#   'Body': ['Shape\nSquare Shoulder',
#    'Top Material\nSitka spruce',
#    'Back Material\nRosewood',
#    'Side Material\nRosewood',
#    'Bracing\nTraditional hand-scalloped Advanced X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nRound',
#    'Scale Length\n25.5" / 64.77cm',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Inlays\nMother-of-pearl Parallelogram'],
#   'Hardware': ['Tuners\nGrover Rotomatic w/ Kidney Buttons',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nCustom Line',
#    'Saddle Material\nTusq',
#    'Bridge\nCustom Line',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nRib mounted controls with tu'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACC9YA389/Hummingbird-Chroma',
#   'name': 'Hummingbird Chroma ',
#   'price': '$3,999.00',
#   'Body': ['Shape\nAcoustic',
#    'Top Material\nSitka spruce',
#    'Back Material\nQuilt Maple',
#    'Side Material\nQuilt Maple',
#    'Bracing\nTraditional hand-scalloped Advanced X-bracing',
#    'Binding\nMulti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nTwo-piece maple',
#    'Neck Profile\nAdvanced Response',
#    'Scale Length\n25.5" / 64.77cm',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n16" / 406.4mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nTusq',
#    'Nut Width\n1.725" / 43.82mm',
#    'Inlays\nMother-of-pearl Split Blo'],
#   'Hardware': ['Tuners\nMini Grover Rotomatic',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nHummingbird Avant Garde',
#    'Saddle Material\nTusq',
#    'Bridge\nTraditional belly up',
#    'Bridge Pins\nTusq'],
#   'Electronics': ['Controls\nConvenient soundhole-located'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCH54751/J-45-Montana-Custom',
#   'name': 'J-45 Montana Custom',
#   'price': '$6,599.00',
#   'Body': ['Shape\nRound Shoulder',
#    'Top Material\nAdirondack Red Spruce',
#    'Back Material\nFigured Mahogany',
#    'Side Material\nFigured Mahogany',
#    'Bracing\nTraditional hand scalloped x-bracing',
#    'Binding\nMuti-ply top, single-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nSlim Taper',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nBone',
#    'Nut Width\n1.725" / 43.815mm',
#    'Inlays\nBuffalo Skull'],
#   'Hardware': ['Tuners\nGrover Rotomatic',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nTear drop with buffalo design',
#    'Saddle Material\nBone',
#    'Bridge\nTraditional belly up',
#    'Bridge Pins\nBon'],
#   'Electronics': ['Controls\nVolume and Tone controls in soundh'],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCEDF483/Hummingbird-Custom',
#   'name': 'Hummingbird Custom',
#   'price': '$7,499.00',
#   'Body': ['Shape\nSquare Shoulder',
#    'Top Material\nSitka spruce',
#    'Back Material\nKoa',
#    'Side Material\nKoa',
#    'Bracing\nTraditional hand scalloped x-bracing',
#    'Binding\nMulti-ply top, multi-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nRound',
#    'Scale Length\n24.75" / 62.865cm',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nBone',
#    'Nut Width\n1.725" / 43.815mm',
#    'Inlays\nHummingbird Custom'],
#   'Hardware': ['Tuners\nGrover, engraved kidney knobs',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nHummingbird, Mother-of-pearl inlay',
#    'Saddle Material\nBone',
#    'Bridge\nTraditional belly up',
#    'Bridge Pins\nTusq'],
#   'Electronics': [''],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/ACCAE9604/Firebird',
#   'name': 'Firebird',
#   'price': '$5,199.00',
#   'Body': ['Shape\nAcoustic',
#    'Top Material\nSitka spruce',
#    'Back Material\nQuilt Maple',
#    'Side Material\nQuilt Maple',
#    'Bracing\nTraditional hand scalloped x-bracing',
#    'Binding\nMulti-ply top, multi-ply back',
#    'Finish\nNitrocellulose'],
#   'Neck': ['Material\ntwo-piece maple',
#    'Neck Profile\nRound',
#    'Scale Length\n25.5" / 64.77cm',
#    'Fingerboard Material\nRichlite',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nStandard',
#    'Nut Material\nBone',
#    'Nut Width\n1.72" / 43.68mm',
#    'Inlays\nMother-of -pearl and abalone flames'],
#   'Hardware': ['Tuners\nGrover Keystone',
#    'Tuner Plating\nGold',
#    'Truss Rod Cover\nB/W',
#    'Pick Guard\nHummingbird with flames',
#    'Saddle Material\nBone',
#    'Bridge\nTraditional belly up',
#    'Bridge Pins\nBon'],
#   'Electronics': [''],
#   'Miscellaneous': ['Strings\n0.053, 0.042, 0.032, 0.024, 0.016, 0.012',
#    'Case\nGibson Hardshell',
#    'Included Accessories\nIncludes Gibson Accessory Kit']}]

# %%
Gibson_Crawling_Moduel.BASE_DIR
# Out:
# 'C:\\Users\\User\\Documents\\python_basic'
