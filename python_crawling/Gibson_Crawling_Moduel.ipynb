# %%
import requests
from bs4 import BeautifulSoup
from pprint import pprint
import os
import pandas as pd 
        
intro = """
Les-Paul, SG, ES, Acoustic, Designer, Bass 를 'crl.run( )'안에 입력하세요.
\n입력한 값에 대한 깁슨 홈페이지에 있는 모든 깁슨 모델을 제공합니다.
"""
maker = 'jhkang1517@gmail.com'

BASE_DIR = os.getcwd()

class crl():
    def __init__(self, base_dir):
        self.base_dir = BASE_DIR
    
    def run(model):         
        PICTURE_DIR = os.path.join(BASE_DIR, 'guitar_pictures_{}'.format(model))
        
        if not os.path.exists(PICTURE_DIR):
            os.makedirs(PICTURE_DIR)
    
        guitar_list = []
        gibson_usl = "https://www.gibson.com/Guitars/" + model
        resp = requests.get(gibson_usl) 
        soup = BeautifulSoup(resp.content, 'html.parser') 
        gibson_contents = soup.find('div', class_='row pb-5').find_all('div', class_='col-sm-12 col-md-6 col-lg-4 px-2 mb-4')

        for div in gibson_contents:
            guitar_dict = {}

            a_tag = div.find('h4').find('a')
            guitar_dict['link'] = 'https://www.gibson.com'+a_tag['href'] 
            guitar_dict['name'] = a_tag.text
    
            b_tag = div.find('div', class_='price-label ml-3').find('span')
            guitar_dict['price'] = b_tag.text.strip()
            
            detail_resp = requests.get('https://www.gibson.com'+a_tag['href'])
            detail_soup = BeautifulSoup(detail_resp.content, 'html.parser')
            detail_content = detail_soup.find('div', class_='gibson-card py-4')
    
            d_tag = detail_content.find('div', class_='spec-section body-specs pb-4 mb-4')
            e_tag = detail_content.find('div', class_='spec-section neck-specs mb-4')
            f_tag = detail_content.find('div', class_='spec-section hardware-specs mb-4')
            g_tag = detail_content.find('div', class_='spec-section electronics-specs mb-4')
            h_tag = detail_content.find('div', class_='spec-section miscellaneous-specs mb-4')

            guitar_dict['Body'] = d_tag.text.strip('\nBody\n\n ').split("\n\n\n")
            guitar_dict['Neck'] = e_tag.text.strip('\nNeck\n\n ').split("\n\n\n")
            guitar_dict['Hardware'] = f_tag.text.strip('\nHardware\n\n ').split("\n\n\n")
            guitar_dict['Electronics'] = g_tag.text.strip('\nElectronics\n\n ').split("\n\n\n")
            guitar_dict['Miscellaneous'] = h_tag.text.strip('\nMiscellaneous\n\n ').split("\n\n\n")
    
            guitar_list.append(guitar_dict)
    
            c_tag = div.find('img')
            img_url = c_tag['src']
            img_resp = requests.get(img_url)
            p_filename = img_url.split('/')[-4:]
            filename = "".join(p_filename)
            guitar_picture_path = os.path.join(PICTURE_DIR, filename)  
            with open(guitar_picture_path, 'wb') as f:
                f.write(img_resp.content)

        print("총",len(guitar_list),"개의 결과물이 있습니다." )
        print("Gibson Accessory Kit의 주소는 https://www.gibson.com/Gear/Accessories/G-CAREKIT1 입니다.")
        return  guitar_list

# %%
crl.run('Bass')
# Out:
# 총 7 개의 결과물이 있습니다.
# Gibson Accessory Kit의 주소는 https://www.gibson.com/Gear/Accessories/G-CAREKIT1 입니다.
# [{'link': 'https://www.gibson.com/Guitar/USANRD503/EB-Bass-4-String-2019',
#   'name': 'EB Bass 4 String 2019',
#   'price': '$1,149.00',
#   'Body': ['Material\nSwamp Ash',
#    'Weight Relief\nNone',
#    'Finish\nSatin Nitrocellulose Lacquer'],
#   'Neck': ['Material\nMaple',
#    'Neck Profile\nRounded',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n24',
#    'Frets\nMedium - Cryogenically Treated',
#    'Nut Material\nTektoid',
#    'Nut Width\n1.625" / 41.28mm',
#    'End-of-Board Width\n2.484" / 63.09mm',
#    'Inlays\nAcrylic Dots'],
#   'Hardware': ['Finish\nChrome',
#    'Bridge\nBABICZ Full Contact',
#    'Tuners\nGrover Bass Keys',
#    'Control Knobs\nKnurled Chrome Knob',
#    'Jack Plate\nBlack'],
#   'Electronics': ['Neck Pickup\nRhythm EB Bass',
#    'Bridge Pickup\nLead EB Bass',
#    'Controls\n2 Push/Pull Volumes (Coil Tap) & 1 Master T'],
#   'Miscellaneous': ['Strings\n.045, .065, .085, .105',
#    'Case\nDesigner Series Gig Bag',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/USAKUC232/Thunderbird-Bass',
#   'name': 'Thunderbird Bass',
#   'price': '$2,299.00',
#   'Body': ['Material\nMahogany',
#    'Weight Relief\nNone',
#    'Finish\nGloss Nitrocellulose Lacquer'],
#   'Neck': ['Material\n9-ply Mahogany/Walnut',
#    'Neck Profile\nRounded',
#    'Scale Length\n34" / 86.36cm',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nMedium Jumbo',
#    'Nut Material\nGraph Tech',
#    'Nut Width\n1.5" / 38.1mm',
#    'End-of-Board Width\n2.32" / 58.93mm',
#    'Inlays\nAcrylic Dots'],
#   'Hardware': ['Finish\nChrome',
#    'Bridge\n3-Point Adjustable',
#    'Tuners\nGrover Bass Keys',
#    'Pick Guard\nWhite 3-ply',
#    'Control Knobs\nBlack Tophats w/ Silver Inserts'],
#   'Electronics': ['Neck Pickup\nRhythm T-Bird',
#    'Bridge Pickup\nLead T-Bird',
#    'Controls\n2 Volumes & 1 Master T'],
#   'Miscellaneous': ['Strings\n.045, .065, .085, .105',
#    'Case\nHard Shell Case',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/USACYC512/Les-Paul-Junior-Tribute-DC-Bass',
#   'name': 'Les Paul Junior Tribute DC Bass',
#   'price': '$999.00',
#   'Body': ['Material\nMahogany',
#    'Weight Relief\nNone',
#    'Finish\nSatin Nitrocellulose Lacquer'],
#   'Neck': ['Material\nMaple',
#    'Neck Profile\nRounded',
#    'Scale Length\n30.5" / 77.47cm',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nMedium Jumbo',
#    'Nut Material\nGraph Tech',
#    'Nut Width\n1.6" / 40.64mm',
#    'End-of-Board Width\n2.32" / 58.93mm',
#    'Inlays\nAcrylic Dots'],
#   'Hardware': ['Finish\nChrome',
#    'Bridge\n3-Point Adjustable',
#    'Tuners\nHipshot Ultra-Light Mini-Clovers',
#    'Pick Guard\nBlack 5-ply',
#    'Control Knobs\nBlack Top Hats',
#    'Jack Plate\nBlack'],
#   'Electronics': ['Neck Pickup\nBassBucker',
#    'Controls\n1 Push/Pull Volume (Coil-Tap) & 1 T'],
#   'Miscellaneous': ['Strings\n.045, .065, .085, .105',
#    'Case\nDesigner Series Gig Bag',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/USABCH291/SG-Standard-Bass',
#   'name': 'SG Standard Bass',
#   'price': '$1,499.00',
#   'Body': ['Material\nMahogany',
#    'Weight Relief\nNone',
#    'Finish\nGloss Nitrocellulose Lacquer'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nRounded',
#    'Scale Length\n30.5" / 77.47cm',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nMedium Jumbo',
#    'Nut Material\nGraph Tech',
#    'Nut Width\n1.6" / 40.64mm',
#    'End-of-Board Width\n2.32" / 58.93mm',
#    'Inlays\nAcrylic Trapezoid'],
#   'Hardware': ['Finish\nChrome',
#    'Bridge\n3-Point Adjustable',
#    'Tuners\nGrover Shamrocks',
#    'Pick Guard\nBlack 5-ply',
#    'Control Knobs\nBlack Tophats w/ Silver Inserts'],
#   'Electronics': ['Neck Pickup\nRhythm SG Bass',
#    'Bridge Pickup\nLead SG Bass',
#    'Controls\n2 Volumes & 1 Master T'],
#   'Miscellaneous': ['Strings\n.045, .065, .085, .105',
#    'Case\nHard Shell Case',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/USAXG5792/SG-Standard-Bass-2019',
#   'name': 'SG Standard Bass 2019',
#   'price': '$1,499.00',
#   'Body': ['Material\nMahogany',
#    'Weight Relief\nNone',
#    'Finish\nGloss Nitrocellulose Lacquer'],
#   'Neck': ['Material\nMahogany',
#    'Neck Profile\nRounded',
#    'Scale Length\n30.5" / 77.47cm',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n12" / 304.8mm',
#    'Number of Frets\n20',
#    'Frets\nMedium - Cryogenically Treated',
#    'Nut Material\nTektoid',
#    'Nut Width\n1.6" / 40.64mm',
#    'End-of-Board Width\n2.32" / 58.93mm',
#    'Inlays\nAcrylic Trapezoid'],
#   'Hardware': ['Finish\nChrome',
#    'Bridge\n3-Point Adjustable',
#    'Tuners\nGrover Shamrocks',
#    'Pick Guard\nBlack 5-ply',
#    'Control Knobs\nBlack Tophats w/ Silver Inserts'],
#   'Electronics': ['Neck Pickup\nRhythm SG Bass',
#    'Bridge Pickup\nLead SG Bass',
#    'Controls\n2 Volumes & 1 Master T'],
#   'Miscellaneous': ['Strings\n.045, .065, .085, .105',
#    'Case\nHard Shell Case',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/USA9U9161/EB-Bass-5-String-2019',
#   'name': 'EB Bass 5 String 2019',
#   'price': '$1,249.00',
#   'Body': ['Material\nSwamp Ash',
#    'Weight Relief\nNone',
#    'Finish\nSatin Nitrocellulose Lacquer'],
#   'Neck': ['Material\nMaple',
#    'Neck Profile\nRounded',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n21" / 533.4mm',
#    'Number of Frets\n24',
#    'Frets\nMedium - Cryogenically Treated',
#    'Nut Material\nTektoid',
#    'Nut Width\n1.75" / 44.45mm',
#    'End-of-Board Width\n3.125" / 79.38mm',
#    'Inlays\nAcrylic Dots'],
#   'Hardware': ['Finish\nChrome',
#    'Bridge\nBABICZ Full Contact',
#    'Tuners\nGrover Bass Keys',
#    'Control Knobs\nKnurled Chrome Knob',
#    'Jack Plate\nBlack'],
#   'Electronics': ['Neck Pickup\nRhythm EB Bass',
#    'Bridge Pickup\nLead EB Bass',
#    'Controls\n2 Push/Pull Volumes (Coil Tap) & 1 Master T'],
#   'Miscellaneous': ['Strings\n.045, .065, .085, .105, 1.25',
#    'Case\nDesigner Series Gig Bag',
#    'Included Accessories\nIncludes Gibson Accessory Kit']},
#  {'link': 'https://www.gibson.com/Guitar/USAFQL802/Thunderbird-Bass-2019',
#   'name': 'Thunderbird Bass 2019',
#   'price': '$2,299.00',
#   'Body': ['Material\nMahogany', 'Finish\nGloss Nitrocellulose Lacquer'],
#   'Neck': ['Material\n9-ply Mahogany/Walnut',
#    'Neck Profile\nRounded Neck Profile',
#    'Scale Length\n34" / 86.36cm',
#    'Fingerboard Material\nRosewood',
#    'Fingerboard Radius\n0.472" / 12mm',
#    'Number of Frets\n20',
#    'Frets\nMedium Jumbo',
#    'Nut Material\nTektoid',
#    'Nut Width\n1.5" / 38.1mm',
#    'End-of-Board Width\n2.26" / 57.4mm',
#    'Inlays\nAcrylic Dots'],
#   'Hardware': ['Finish\nChrome',
#    'Bridge\n3-Point Adjustable',
#    'Tuners\nGrover Bass Keys',
#    'Pick Guard\nWhite 3-ply',
#    'Control Knobs\nBlack Tophats w/ Silver Inserts'],
#   'Electronics': ['Neck Pickup\nRhythm T-Bird',
#    'Bridge Pickup\nLead T-Bird',
#    'Controls\n2 Volumes & 1 Master T'],
#   'Miscellaneous': ['Strings\n.045, .065, .085, .105',
#    'Case\nHard Shell Case',
#    'Included Accessories\nIncludes Gibson Accessory Kit']}]
