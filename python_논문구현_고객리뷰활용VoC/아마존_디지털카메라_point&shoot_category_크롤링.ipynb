# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.amazon.com/s/ref=lp_281052_nr_n_0?fst=as%3Aoff&rh=n%3A172282%2Cn%3A%21493964%2Cn%3A502394%2Cn%3A281052%2Cn%3A330405011&bbn=281052&ie=UTF8&qid=1564987188&rnid=281052"
User_Agent = {'Mozilla': '5.0',
              'AppleWebKit': '537.36',
              'Chrome':'75.0.3770.142',
              'Safari':'537.36'
             }

response = requests.get(url, headers = User_Agent)
# response.content

# %%
soup = BeautifulSoup(response.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo"><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/><!--  emit CSM JS -->
# <style>
# ...

# %%
point_n_shoot = soup.find('div', id='mainResults')
point_n_shoot
# Out:
# <div class="a-row s-result-list-parent-container" id="mainResults"><ul class="s-result-list s-col-3 s-col-ws-4 s-result-list-hgrid s-height-equalized s-grid-view s-text-condensed" data-columns='{"0":1,"522":3,"348":2}'><li class="s-result-item celwidget" data-asin="B07VPQV7BY" data-result-rank="0" id="result_0"><div class="s-item-container"><div class="a-row a-spacing-top-micro a-spacing-micro"><div class="a-row sx-badge-region"><div class="a-row a-spacing-large"></div></div></div><div class="a-row a-spacing-base"><div aria-hidden="true" class="a-column a-span12 a-text-left"><div class="a-section a-spacing-none a-inline-block s-position-relative"><a class="a-link-normal a-text-normal" href="https://www.amazon.com/Sony-Premium-Compact-1-0-type-DSCRX100M7/dp/B07VPQV7BY"><img alt="Sony RX100 VII Premium Compact Camera with 1.0-type stacked CMOS sensor (DSCRX100M7)" class="s-access-image cfMarker" data-search-image-load="" height="160" src="https://images-na.ssl-images-amazon.com/images/
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = ""
User_Agent = {'Mozilla': '5.0',
              'AppleWebKit': '537.36',
              'Chrome':'75.0.3770.142',
              'Safari':'537.36'
             }

# 1. 제품들이 있는 페이지 접속
# 2. 제품 url 접속
# 3. 제품 url -> review가 있는 페이지 접속
# 4. review에 있는 요소들 crawling, and 'Next Page'눌러서 다음 page로 넘어가고 계속해서 수집
