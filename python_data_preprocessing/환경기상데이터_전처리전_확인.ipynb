# %%
# import moduel
import pandas as pd
import numpy as np
import os 
from os import listdir
import re
import matplotlib.pyplot as plt
# %matplotlib inline

def Boxplot(csvpath, outpath):
    base_dir = os.getcwd() # 현재 작업 dir 확인
    print("현재 작업 폴더: ", base_dir)

    # 데이터가 들어있는 폴더
    data_dir = csvpath
    print("데이터 폴더: ", data_dir)
    
    # 데이터가 들어있는 폴더로 작업하는 폴더 경로 변경
    working_dir = os.chdir(data_dir) 
    
    # 전처리된 데이터를 내보낼 폴더
    out_dir = outpath
    if not os.path.exists(out_dir): # 만약 경로가 없으면, 
            os.makedirs(out_dir) # 새로운 폴더를 생성하겠습니다.
            
    # 전처리할 파일들이 들어있는 폴더의 파일 목록을 list형태로 추출
    files = os.listdir(data_dir)
    
    # for문을 돌면서 하나씩 파일을 꺼내옴
    for file in files:
        df = pd.read_csv(file, index_col=0)
        # 데이터 결측치 처리 code -> Not a Number로 변경
        df = df.replace([-999,-9999],[np.nan, np.nan])
        
        # boxplot code
#         plt.figure(figsize=(10,10))
#         boxplot = df.boxplot(column=['pm10', 'pm25'])
#         plt.yticks(np.arange(0, 100, step=10))
#         plt.show()
        
        # histogram code
#         print("pm10 \n")
#         plt.hist(df['pm10])
#         plt.show()
        
#         print("pm25 \n")
#         plt.hist(df['pm25'])
#         plt.show()
#         print("="*50)

        # 꺾은선 그래프 code
        x = df.index
        y = df['pm10']
        plt.scatter(x, y)
        plt.show()
        
#         x = df.index
#         z = df['pm25']
#         plt.plot(x,z)

#         plt.show()

# %%
csvpath = r'C:\Users\User\Documents\data_weatherforcast\노원구'
outpath = r'C:\Users\User\Documents\data_weatherforcast\노원구_데이터확인'

Boxplot(csvpath, outpath)
# Out:
# 현재 작업 폴더:  C:\Users\User\Documents\data_weatherforcast\노원구
# 데이터 폴더:  C:\Users\User\Documents\data_weatherforcast\노원구
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-90-a11b034e08c0> in <module>
#       2 outpath = r'C:\Users\User\Documents\data_weatherforcast\노원구_데이터확인'
#       3
# ----> 4 Boxplot(csvpath, outpath)
#
# <ipython-input-89-34924b45e1a9> in Boxplot(csvpath, outpath)
#      53         y = df['pm10']
#      54         plt.scatter(x, y)
# ---> 55         plt.show()
#      56
#      57 #         x = df.index
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     252     """
#     253     global _show
# --> 254     return _show(*args, **kw)
#     255
#     256
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
# ...

# %%
plt.figure?

# %%
plt.hist?

# %%
plt?

# %%
def Check(csvpath):
    base_dir = os.getcwd() # 현재 작업 dir 확인
    print("현재 작업 폴더: ", base_dir)

    # 데이터가 들어있는 폴더
    data_dir = csvpath
    print("데이터 폴더: ", data_dir)
    
    # 데이터가 들어있는 폴더로 작업하는 폴더 경로 변경
    working_dir = os.chdir(data_dir) 
            
    # 전처리할 파일들이 들어있는 폴더의 파일 목록을 list형태로 추출
    files = os.listdir(data_dir)
    
    # for문을 돌면서 하나씩 파일을 꺼내옴
    for file in files:
        df = pd.read_csv(file, index_col=0)
        
        # boxplot code
#         plt.figure(figsize=(10,10))
#         boxplot = df.boxplot(column=['미세먼지(PM-10)', '초미세먼지(PM-2.5)'])
#         plt.yticks(np.arange(0, 100, step=10))
#         plt.show()
        
        # histogram code
#         print("pm10 \n")
#         plt.hist(df['미세먼지(PM-10)'])
#         plt.show()
        
#         print("pm25 \n")
#         plt.hist(df['초미세먼지(PM-2.5)'])
#         plt.show()
#         print("="*50)

        # 꺾은선 그래프 code
        x = df.index
        y = df['미세먼지(PM-10)']
        plt.plot(x, y)
        plt.show()
        
#         x = df.index
#         z = df['초미세먼지(PM-2.5)']
#         plt.plot(x,z)

#         plt.show()

# %%
rcsvpath = r'C:\Users\User\Documents\data_weatherforcast\노원구_데이터확인'
routpath = r'C:\Users\User\Documents\data_weatherforcast\노원구_데이터확인'

Check(rcsvpath)
# Out:
# 현재 작업 폴더:  C:\Users\User\Documents\data_weatherforcast\노원구_데이터확인
# 데이터 폴더:  C:\Users\User\Documents\data_weatherforcast\노원구_데이터확인
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-105-f112453bd528> in <module>
#       2 routpath = r'C:\Users\User\Documents\data_weatherforcast\노원구_데이터확인'
#       3
# ----> 4 Check(rcsvpath)
#
# <ipython-input-103-f673881fc3c0> in Check(csvpath)
#      37         y = df['미세먼지(PM-10)']
#      38         plt.plot(x, y)
# ---> 39         plt.show()
#      40
#      41 #         x = df.index
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     252     """
#     253     global _show
# --> 254     return _show(*args, **kw)
#     255
#     256
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
# ...
